# %%
import pandas as pd
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def tratamento_texto(texto):
    texto = texto.lower()
    texto = texto.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(texto)
    stop_words = set(stopwords.words("english"))
    tokens = [palavra for palavra in tokens if palavra not in stop_words]
    return ' '.join(tokens)
def obter_similaridade_manual(query, dataFrame, top):
    tokens_consulta = word_tokenize(tratamento_texto(query))
    lista_tokens = [word_tokenize(descricao) for descricao in dataFrame["texto_tratado"]]

    bag_of_words_set = set()
    for tokens in lista_tokens:
        bag_of_words_set.update(tokens)
    bag_of_words = list(bag_of_words_set)
    vetor_consulta = [tokens_consulta.count(palavra) for palavra in bag_of_words]

    lista_vetores = []
    for tokens in lista_tokens:
        vetor = [tokens.count(palavra) for palavra in bag_of_words]
        lista_vetores.append(vetor)

    def valor_cosseno(v1, v2):
        u = np.array(v1)
        v = np.array(v2)
        cos = np.dot(u,v)/((np.linalg.norm(u))*(np.linalg.norm(v)))
        return cos
    
    recomendacao = dataFrame
    recomendacao["Similaridade"] = [valor_cosseno(vetor_consulta, v) for v in lista_vetores]
    recomendacao = recomendacao.sort_values("Similaridade", ascending=False)
    return recomendacao.head(top)

# %%
df = pd.read_csv("dataset/events.csv", sep=";")

# %%
df = df.head(5000)

# %%
similaridade = obter_similaridade_manual("Roman war", df, 30)

# %%
similaridade
# Out:
#       Year    Date                                              Event  \
# 449    457  Dec 28  Roman armies proclaim Majorian Emperor of the ...
# 481    475  Aug 28  Roman general Orestes forces western Roman Emp...
# 222    305   May 1  Roman Emperors Retire\n Diocletian and Maximia...
# 469    472  Aug 19  Ricimer, Germanic Roman general (kingmaker in ...
# 442    455   Jul 9  Roman military commander Avitus is proclaimed ...
# 352    393  Jan 23  Roman Empire\n Roman Emperor Theodosius I proc...
# 338    383  Jan 19  Roman Empire\n Roman Emperor Theodosius I proc...
# 467    472  Jul 11  Anthemius, Emperor of the Western Roman Empire...
# 3452  1348  Nov 20  Stefano Colonna, Roman senator, dies in battle...
# 336    381  Jan 10  Roman Empire\n Roman Emperor Theodosius issues...
# 122    161   Mar 7  1st Co-Emperors\n Roman Emperor Antoninus Pius...
# 328    375  Nov 17  Valentinian I "The Great", Roman Co-Emperor an...
# 315    365  Sep 28  Roman usurper Procopius bribes two legions pas...
# 371    404   Oct 6  Aelia Eudoxia, Eastern Roman empress, wife of ...
# 238    311  Apr 30  Roman Emperor Galerius issues the Edict of Tol...
# 49      54  Oct 13  Death of Claudius\n Agrippina the Younger murd...
# 225    306   Mar 4  Martyrdom of Saint Adrian of Nicomedia, a Roma...
